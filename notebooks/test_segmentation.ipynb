# %% [markdown]
# # Python implementation of HMRF-GMM segmentation test

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data_file = "../F01_ME_H118_1m.csv"
loc_file = "../F01_ME_H118_loc.csv"

# %%
data = np.loadtxt(data_file, skiprows=1, delimiter=",")

# %% [markdown]
# Restructure data file:

# %%
x_vals = data[:,0]
y_vals = data[:,1]
var1 = data[:,2]
var2 = data[:,3]

# %%
plt.scatter(x_vals, y_vals, c=var1)

# %% [markdown]
# Load second data set:

# %%
import scipy.io

# %%
data2 = scipy.io.loadmat("../NDVI.mat")

# %%
data2.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'NDVI', 'x', 'y'])

# %%
data2['x'].shape, data2['y'].shape
# Out:
# ((1, 1200), (1, 800))

# %%
X,Y = np.meshgrid(data2['x'], data2['y'])

# %%
data2['NDVI'].shape
# Out:
# (800, 1200)

# %%
plt.imshow(data2['NDVI'])
